# %% [markdown]
# <a href="https://colab.research.google.com/github/nursedakarabacak/beginnerpython/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
#ilk olarak driva bağlayalım
from google.colab import drive
drive.mount('/content/drive')
#2. olarak indirme yapılacak klasore gidelim
os.chdir('/content/drive/MyDrive/tubitak_proje')
#veriyi indirme komutu
dataset_url = "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Amazon_Fashion.jsonl.gz"
print("Veri indiriliyor...")
# !wget {dataset_url}

print("İndirme tamamlandı! Dosyalarınız arasında .json.gz uzantılı dosyayı görmelisiniz.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Veri indiriliyor...
# --2025-11-29 13:40:30--  https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Amazon_Fashion.jsonl.gz
# Resolving mcauleylab.ucsd.edu (mcauleylab.ucsd.edu)... 169.228.63.88
# Connecting to mcauleylab.ucsd.edu (mcauleylab.ucsd.edu)|169.228.63.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 292425439 (279M) [application/gzip]
# Saving to: ‘Amazon_Fashion.jsonl.gz.1’
#
# shion.jsonl.gz.1     22%[===>                ]  63.69M  17.8MB/s    eta 14s    ^C
# İndirme tamamlandı! Dosyalarınız arasında .json.gz uzantılı dosyayı görmelisiniz.

# %%
dataset_url = "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Amazon_Fashion.jsonl.gz"
dosya_adi = "Amazon_Fashion.jsonl.gz"

if not os.path.exists(dosya_adi):
    print(f"{dosya_adi} indiriliyor...")
    # !wget {url} -O {dosya_adi}
    print("İndirme tamamlandı.")
else:
    print(f"{dosya_adi} zaten mevcut.")

# 2. Veriyi Pandas ile Okuma (JSON Lines formatı için)
print("Veri okunuyor, lütfen bekleyin...")

# Bu veri seti büyük olabilir, o yüzden 'chunk' (parça parça) okumak RAM'i şişirmemek için daha güvenlidir.
# Ancak Fashion veri seti muhtemelen Colab RAM'ine sığar.
try:
    df = pd.read_json(dosya_adi, lines=True, compression='gzip')
    print("Veri başarıyla yüklendi!")
except ValueError as e:
    print("Hata oluştu:", e)

# 3. İlk 5 Satırı ve Sütun Bilgilerini Görelim
print(f"\nToplam Yorum Sayısı: {len(df)}")
display(df.head())
print("\nSütun İsimleri ve Veri Tipleri:")
print(df.info())
# Out:
# Amazon_Fashion.jsonl.gz zaten mevcut.
# Veri okunuyor, lütfen bekleyin...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1021742397.py in <cell line: 0>()
#      15 # Ancak Fashion veri seti muhtemelen Colab RAM'ine sığar.
#      16 try:
# ---> 17     df = pd.read_json(dosya_adi, lines=True, compression='gzip')
#      18     print("Veri başarıyla yüklendi!")
#      19 except ValueError as e:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...

# %%
#gerekli sütünları seçme
hedef_sutunlar = ['user_id','timestamp','rating','title','text','parent_asin']
df_clean=df[hedef_sutunlar].copy()
#eksik verileri temizleme
#text ve user_id olmayan satırlar işimize yaramaz
print(f"Temizlik öncesi satır sayısı:{len(df_clean)}")
df_clean.dropna(subset=['user_id', 'text'], inplace=True)
print(f"Temizlik sonrası satır sayısı: {len(df_clean)}")
#3. adım metin birleştirme
#title ve text birleştirip full review yapalım.boş title vars sadece texti alsın diye fillna kullanıcağız
df_clean['title'] = df_clean['title'].fillna('')
df_clean['full_review'] = df_clean['title'] + " " + df_clean['text']
#4.adım tarih formati düzenleme
df_clean['date'] = pd.to_datetime(df_clean['timestamp'], unit='ms')

display(df_clean[['user_id', 'date', 'rating', 'full_review']].head())

print("\nVeri tipleri kontrolü:")
print(df_clean.dtypes)

#temiz kaydetme
kayit_yolu = '/content/drive/MyDrive/Tubitak_Proje/amazon_fashion_temizlenmis.csv'
df_clean.to_csv(kayit_yolu, index=False)
# Out:
# Temizlik öncesi satır sayısı:2500939
# Temizlik sonrası satır sayısı: 2500939
#                         user_id                    date  rating  \
# 0  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ 2020-01-09 00:06:34.489       5
# 1  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ 2020-12-20 01:04:06.701       5
# 2  AHITBJSS7KYUBVZPX7M2WJCOIVKQ 2015-05-23 01:33:48.000       2
# 3  AFVNEEPDEIH5SPUN5BWC6NKL3WNQ 2018-12-31 20:57:27.095       1
# 4  AHSPLDNW5OOUK2PLH7GXLACFBZNQ 2015-08-13 14:29:26.000       5
#
#                                          full_review
# 0  Pretty locket I think this locket is really pr...
# 1                                            A Great
# 2  Two Stars One of the stones fell out within th...
# 3  Won’t buy again Crappy socks. Money wasted. Bo...
# 4  I LOVE these glasses I LOVE these glasses!  Th...
# Veri tipleri kontrolü:
# user_id                object
# timestamp      datetime64[ns]
# rating                  int64
# title                  object
# text                   object
# ...
